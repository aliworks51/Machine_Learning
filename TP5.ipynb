# %%
import numpy as np
import matplotlib.pyplot as plt

from keras.datasets import mnist

# import functions ديالك
from TP_MLP_multiclass_mnist_multicouches.py import model, predict, one_hot
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 7
#       4 from keras.datasets import mnist
#       6 # import functions ديالك
# ----> 7 from TP_MLP_multiclass_mnist_multicouches.py import model, predict, one_hot
#
# ModuleNotFoundError: No module named 'TP_MLP_multiclass_mnist_multicouches'
